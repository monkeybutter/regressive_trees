# %%
df
# Out:
#    lin_2000_cc_test  lin_2000_rmse_test  lin_2000_cc_train  \
# 0          0.757255            1.837361           0.758257
# 1          0.757643            1.836092           0.758158
# 2          0.756997            1.838201           0.758267
# 3          0.757284            1.837268           0.758241
# 4          0.757488            1.836597           0.758208
#
#    lin_2000_rmse_train  cir_2000_cc_test  cir_2000_rmse_test  \
# 0             1.834085          0.756689            1.839208
# 1             1.834407          0.757304            1.837201
# 2             1.834051          0.756025            1.841368
# 3             1.834138          0.756639            1.839377
# 4             1.834246          0.756038            1.841325
#
#    cir_2000_cc_train  cir_2000_rmse_train  lin_1000_cc_test  \
# 0           0.758332             1.833840          0.788377
# 1           0.758811             1.832271          0.788240
# ...

# %%
import numpy as np
import pandas as pd
import seaborn as sb

airports = ["yssy", "egll", "zbaa", "eddt", "lebl", "limc", "lfpg"]

for airport in airports:
    
    df = pd.read_csv("/home/roz016/Dropbox/Data for Tree/Results/new_tree_cx10_lin_vs_cir/wind_spd_{}_hope.csv".format(airport))

    index = [2000, 1000, 500, 200, 100, 50]
    #new_df = pd.DataFrame(index=index, columns=["linear_train", "circular_train", "linear_test", "circular_test"])
    new_df = pd.DataFrame(index=index, columns=["linear_test", "circular_test"])
    new_df = new_df.fillna(0) # with 0s rather than NaNs

    for i in index:
        #new_df.ix[i, 'linear_train'] = np.mean(df["lin_" + str(i) + "_rmse_train"])
        #new_df.ix[i, 'circular_train'] = np.mean(df["cir_" + str(i) + "_rmse_train"])
        new_df.ix[i, 'linear_test'] = np.mean(df["lin_" + str(i) + "_rmse_test"])
        new_df.ix[i, 'circular_test'] = np.mean(df["cir_" + str(i) + "_rmse_test"])


    new_df.plot(title= airport, xticks=index, logx=True)

# %%
import numpy as np
import pandas as pd

airports = ["yssy", "egll", "zbaa", "eddt", "lebl", "limc", "lfpg"]

for airport in airports:
    
    df = pd.read_csv("/home/roz016/Dropbox/Data for Tree/Results/new_tree_cx10_lin_vs_cir/wind_spd_{}_hope.csv".format(airport))

    index = [2000, 1000, 500, 200, 100, 50]
    new_df = pd.DataFrame(index=index, columns=["linear_train", "circular_train", "linear_test", "circular_test"])
    new_df = new_df.fillna(0) # with 0s rather than NaNs

    for i in index:
        new_df.ix[i, 'linear_train'] = np.mean(df["lin_" + str(i) + "_cc_train"])
        new_df.ix[i, 'circular_train'] = np.mean(df["cir_" + str(i) + "_cc_train"])
        new_df.ix[i, 'linear_test'] = np.mean(df["lin_" + str(i) + "_cc_test"])
        new_df.ix[i, 'circular_test'] = np.mean(df["cir_" + str(i) + "_cc_test"])


    new_df.plot(title= airport, xticks=index, logx=True)

# %%
import numpy as np
import pandas as pd

airports = ["yssy", "egll", "zbaa"]

for airport in airports:
    
    df = pd.read_csv("/home/roz016/Dropbox/Data for Tree/Results/new_tree_cx10_lin_vs_cir/temp_{}.csv".format(airport))

    index = [2000, 1000, 500, 200, 100, 50]
    new_df = pd.DataFrame(index=index, columns=["linear_train", "circular_train", "linear_test", "circular_test"])
    new_df = new_df.fillna(0) # with 0s rather than NaNs

    for i in index:
        new_df.ix[i, 'linear_train'] = np.mean(df["lin_" + str(i) + "_cc_train"])
        new_df.ix[i, 'circular_train'] = np.mean(df["cir_" + str(i) + "_cc_train"])
        new_df.ix[i, 'linear_test'] = np.mean(df["lin_" + str(i) + "_cc_test"])
        new_df.ix[i, 'circular_test'] = np.mean(df["cir_" + str(i) + "_cc_test"])


    new_df.plot(title= airport, xticks=index, logx=True)

# %%
import numpy as np
import pandas as pd

airports = ["yssy", "egll", "zbaa"]

for airport in airports:
    
    df = pd.read_csv("/home/roz016/Dropbox/Data for Tree/Results/new_tree_cx10_lin_vs_cir/wind_spd_{}_winddir_only.csv".format(airport))

    index = [2000, 1000, 500, 200, 100, 50]
    new_df = pd.DataFrame(index=index, columns=["linear_train", "circular_train", "linear_test", "circular_test"])
    new_df = new_df.fillna(0) # with 0s rather than NaNs

    for i in index:
        new_df.ix[i, 'linear_train'] = np.mean(df["lin_" + str(i) + "_cc_train"])
        new_df.ix[i, 'circular_train'] = np.mean(df["cir_" + str(i) + "_cc_train"])
        new_df.ix[i, 'linear_test'] = np.mean(df["lin_" + str(i) + "_cc_test"])
        new_df.ix[i, 'circular_test'] = np.mean(df["cir_" + str(i) + "_cc_test"])


    new_df.plot(title= airport, xticks=index, logx=True)

# %%
import numpy as np
import pandas as pd

airports = ["yssy", "egll", "zbaa"]

for airport in airports:
    
    df = pd.read_csv("/home/roz016/Dropbox/Data for Tree/Results/new_tree_cx10_lin_vs_cir/wind_spd_{}_wind_spd.csv".format(airport))

    index = [2000, 1000, 500, 200, 100, 50]
    new_df = pd.DataFrame(index=index, columns=["linear_train", "linear_test"])
    new_df = new_df.fillna(0) # with 0s rather than NaNs

    for i in index:
        new_df.ix[i, 'linear_train'] = np.mean(df["lin_" + str(i) + "_cc_train"])
        #new_df.ix[i, 'circular_train'] = np.mean(df["cir_" + str(i) + "_cc_train"])
        new_df.ix[i, 'linear_test'] = np.mean(df["lin_" + str(i) + "_cc_test"])
        #new_df.ix[i, 'circular_test'] = np.mean(df["cir_" + str(i) + "_cc_test"])


    new_df.plot(title= airport, xticks=index, logx=True)
